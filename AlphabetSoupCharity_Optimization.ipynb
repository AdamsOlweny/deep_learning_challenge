# %% [markdown]
# ## Preprocessing

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
clean_application_df = application_df.drop(columns=["EIN", "NAME"])
clean_application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
clean_application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
appCounts = clean_application_df["APPLICATION_TYPE"].value_counts()
appCounts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(appCounts[appCounts<500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
classCounts = clean_application_df["CLASSIFICATION"].value_counts()
classCounts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
classCounts1 = classCounts[classCounts>1]
classCounts1
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(classCounts[classCounts<1000].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
num_application_df= pd.get_dummies(clean_application_df)
num_application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                  True
# 1           1    108590              1                 False
# 2           1      5000              0                 False
# 3           1      6692              1                 False
# 4           1    142590              1                 False
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                 False
# 34295       1      5000              0                 False
# 34296       1      5000              0                 False
# 34297       1      5000              1                 False
# 34298       1  36500179              0                 False
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 34294                 False                 False                 False
# 34295                 False                 False                 False
# 34296                 False                 False                 False
# 34297                 False                 False                 False
# 34298                 False                 False                 False
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                     False                 False                 False  ...
# 1                     False                 False                 False  ...
# 2                     False                 False                 False  ...
# 3                     False                 False                 False  ...
# 4                     False                 False                 False  ...
# ...                     ...                   ...                   ...  ...
# 34294                 False                 False                 False  ...
# 34295                 False                 False                 False  ...
# 34296                 False                 False                 False  ...
# 34297                 False                 False                 False  ...
# 34298                 False                 False                 False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  False                   False                     False
# 1                   True                   False                     False
# 2                  False                   False                     False
# 3                  False                    True                     False
# 4                  False                   False                      True
# ...                  ...                     ...                       ...
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   False             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
# ...                   ...               ...                     ...
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                False              False                      True
# 1                False              False                      True
# 2                False              False                      True
# 3                False              False                      True
# 4                False              False                      True
# ...                ...                ...                       ...
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y= num_application_df["IS_SUCCESSFUL"]
X= num_application_df.drop(columns="IS_SUCCESSFUL")
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
y[:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: IS_SUCCESSFUL, dtype: int64

# %%
X[:5]
# Out:
#    STATUS  ASK_AMT  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000                  True                 False
# 1       1   108590                 False                 False
# 2       1     5000                 False                 False
# 3       1     6692                 False                 False
# 4       1   142590                 False                 False
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  ...  \
# 0                 False                 False                False  ...
# 1                 False                 False                False  ...
# 2                 False                 False                False  ...
# 3                 False                 False                False  ...
# 4                 False                 False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 116 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
n_input_features = len(X_train_scaled[0])

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(input_dim=n_input_features,units=80,activation='relu'))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=30,activation='relu'))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1,activation='relu'))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                9360
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 11821 (46.18 KB)
# Trainable params: 11821 (46.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.9202 - accuracy: 0.6993
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7616 - accuracy: 0.7112
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7651 - accuracy: 0.7189
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.7515 - accuracy: 0.7172
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7390 - accuracy: 0.7208
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7385 - accuracy: 0.7250
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7409 - accuracy: 0.7234
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7488 - accuracy: 0.7254
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7085 - accuracy: 0.7230
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7248 - accuracy: 0.7160
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6764 - accuracy: 0.7243
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6754 - accuracy: 0.7289
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6596 - accuracy: 0.7259
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6516 - accuracy: 0.7214
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.7270
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6372 - accuracy: 0.7250
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6034 - accuracy: 0.7286
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6035 - accuracy: 0.7258
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6091 - accuracy: 0.7240
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5945 - accuracy: 0.7258
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5924 - accuracy: 0.7310
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5921 - accuracy: 0.7324
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5895 - accuracy: 0.7315
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6026 - accuracy: 0.7233
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5939 - accuracy: 0.7306
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5998 - accuracy: 0.7298
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5878 - accuracy: 0.7329
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5867 - accuracy: 0.7326
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5887 - accuracy: 0.7242
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5805 - accuracy: 0.7317
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5821 - accuracy: 0.7280
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5813 - accuracy: 0.7338
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5911 - accuracy: 0.7247
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5944 - accuracy: 0.7250
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5936 - accuracy: 0.7313
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6062 - accuracy: 0.7279
# Epoch 37/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5848 - accuracy: 0.7313
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5839 - accuracy: 0.7318
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7338
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5997 - accuracy: 0.7244
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5880 - accuracy: 0.7254
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5696 - accuracy: 0.7350
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5706 - accuracy: 0.7355
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5810 - accuracy: 0.7325
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5794 - accuracy: 0.7347
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5870 - accuracy: 0.7312
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5823 - accuracy: 0.7346
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5935 - accuracy: 0.7343
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5783 - accuracy: 0.7342
# Epoch 50/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5768 - accuracy: 0.7341
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5790 - accuracy: 0.7342
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5756 - accuracy: 0.7338
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5752 - accuracy: 0.7341
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5902 - accuracy: 0.7195
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5872 - accuracy: 0.7159
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5768 - accuracy: 0.7348
# Epoch 57/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5763 - accuracy: 0.7322
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5862 - accuracy: 0.7202
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5764 - accuracy: 0.7327
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5718 - accuracy: 0.7345
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5738 - accuracy: 0.7335
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5726 - accuracy: 0.7338
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5665 - accuracy: 0.7356
# Epoch 64/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5836 - accuracy: 0.7287
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5780 - accuracy: 0.7262
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5723 - accuracy: 0.7327
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7334
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5730 - accuracy: 0.7341
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7353
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7341
# Epoch 71/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5776 - accuracy: 0.7347
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5716 - accuracy: 0.7351
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5766 - accuracy: 0.7294
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6002 - accuracy: 0.7226
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5724 - accuracy: 0.7353
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5683 - accuracy: 0.7366
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5725 - accuracy: 0.7301
# Epoch 78/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5735 - accuracy: 0.7356
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5833 - accuracy: 0.7286
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5740 - accuracy: 0.7356
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5775 - accuracy: 0.7334
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5715 - accuracy: 0.7352
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5837 - accuracy: 0.7348
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5769 - accuracy: 0.7351
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5753 - accuracy: 0.7376
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5724 - accuracy: 0.7348
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5754 - accuracy: 0.7352
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5917 - accuracy: 0.7278
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5771 - accuracy: 0.7341
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5709 - accuracy: 0.7374
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5740 - accuracy: 0.7376
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5930 - accuracy: 0.7219
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6080 - accuracy: 0.7312
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5935 - accuracy: 0.7331
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5752 - accuracy: 0.7331
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5811 - accuracy: 0.7291
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5736 - accuracy: 0.7357
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5798 - accuracy: 0.7357
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5664 - accuracy: 0.7355
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5711 - accuracy: 0.7367

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6149 - accuracy: 0.7314 - 552ms/epoch - 2ms/step
# Loss: 0.6148639917373657, Accuracy: 0.7314285635948181

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("AlphabetSoupCharity_Optimization.h5")
